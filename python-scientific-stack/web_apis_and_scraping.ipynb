# %% [markdown]
# #  Web APIs
#
# An API, or aplication programming interface, is the way programs communicate with one another.
#
# Web APIs are the way programs communicate with one another _over the internet_
#
# [RESTful](https://en.wikipedia.org/wiki/Representational_state_transfer) APIs respect a series of design principles that make them simple to use.
#
# The basic tools we are going to use are: POST and GET requests to urls we'll specify and json objects that we'll receive as response or send as payload (in a POST command, for example).

# %%
import requests

resp = requests.get('http://www.elpais.com/')
resp.content[:500]
# Out:
# b'<!DOCTYPE html>\n<html lang="es">\n<head>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="format-detection" content="address=no,email=no,telephone=no">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0" />\n<title>EL PA\xc3\x8dS: el peri\xc3\xb3dico global</title>\n<meta name="lang" \t\t\tcontent="es" />\n<meta name="author" \t\tcontent="Ediciones El Pa\xc3\xads" />\n<meta name="description" \tcontent="Noticias de \xc3\xbaltima hora sobre la actualidad '

# %%
resp.content
# Out:
# b'<!DOCTYPE html>\n<html lang="es">\n<head>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="format-detection" content="address=no,email=no,telephone=no">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0" />\n<title>EL PA\xc3\x8dS: el peri\xc3\xb3dico global</title>\n<meta name="lang" \t\t\tcontent="es" />\n<meta name="author" \t\tcontent="Ediciones El Pa\xc3\xads" />\n<meta name="description" \tcontent="Noticias de \xc3\xbaltima hora sobre la actualidad en Espa\xc3\xb1a y el mundo: pol\xc3\xadtica, econom\xc3\xada, deportes, cultura, sociedad, tecnolog\xc3\xada, gente, opini\xc3\xb3n, viajes, moda, televisi\xc3\xb3n, los blogs y las firmas de EL PA\xc3\x8dS. Adem\xc3\xa1s especiales, v\xc3\xaddeos, fotos, audios, gr\xc3\xa1ficos, entrevistas, promociones y todos los servicios de EL PA\xc3\x8dS." />\n<meta name="keywords" \t\tcontent="noticias, \xc3\xbaltima hora, actualidad, nacional, Espa\xc3\xb1a, ccaa, internacional, pol\xc3\xadtica, econom\xc3\xada, deportes, cultura, sociedad, tecnolog\xc3\xada, gente, opini\xc3\xb3n, viajes, moda, televisi\xc3\xb3n, blogs, firmas, especiales, v\xc3\xaddeos, fotos, audios, gr\xc3\xa1ficos, entrevistas, servicios" />\n<meta name="date" scheme="W3CDTF" content="2018-12-09T18:56:29+01:00" />\n<meta http-equiv="Refresh" content="900">\n<meta name="organization" content="Ediciones EL PA\xc3\x8dS S.L."/>\n<meta property="article:modified_time" content="2018-12-09T18:56:29+01:00" />\n<meta property="article:publisher" content="https://www.facebook.com/elpais" />\n<meta property="og:title" content="EL PA\xc3\x8dS"/>\n<meta property="og:description" content="Noticias de \xc3\xbaltima hora sobre la actualidad en Espa\xc3\xb1a y el mundo: pol\xc3\xadtica, econom\xc3\xada, deportes, cultura, sociedad, tecnolog\xc3\xada, gente, opini\xc3\xb3n, viajes, moda, televisi\xc3\xb3n, los blogs y las firmas de EL PA\xc3\x8dS. Adem\xc3\xa1s especiales, v\xc3\xaddeos, fotos, audios, gr\xc3\xa1ficos, entrevistas, promociones y todos los servicios de EL PA\xc3\x8dS."/>\n<meta property="og:image" content="https://ep01.epimg.net/iconos/v1.x/v1.0/promos/promo_og_elpais.png"/>\n<meta property="og:image:width" content="200">\n<meta property="og:image:height" content="200">\n<meta property="og:updated_time" content="2018-12-09T18:56:29+01:00" />\n<meta property="og:url" \t\tcontent="https://elpais.com/" />\n<meta property="og:type" \t\tcontent="website"/>\n<meta property="og:site_name"    \tcontent="EL PA\xc3\x8dS"/>\n<meta property="fb:admins" \t\tcontent="851024123, 100008251487379" />\n<meta property="fb:pages"       content="8585811569, 212722845575439, 1397320167179189, 358442097543367, 104260153017742, 171825147183" />\n<meta property="fb:app_id" \t\tcontent="94039431626"/>\n<meta property="twitter:card" \tcontent="summary" />\n<meta property="twitter:site" \tcontent="@el_pais" />\n<link rel="alternate" href="https://elpais.com/rss/elpais/portada_completo.xml" type="application/rss+xml" title="RSS de la portada de EL PA\xc3\x8dS"/>\n<link rel="canonical" href="https://elpais.com/" />\n<link rel="search" href="https://ep01.epimg.net/elpais/xml/opensearch/opensearch.xml" type="application/opensearchdescription+xml" title="elpais.com" />\n<link rel="icon" \t\thref="https://ep01.epimg.net/favicon.png" type="image/png" />\n<link rel="publisher" \thref="https://plus.google.com/+elpais"/>\n<link href="//ep01.epimg.net/estilos/v2.x/v2.1/normalizado.css"  rel="stylesheet" />\n<link href="//ep01.epimg.net/estilos/v2.x/v2.2/comunes.css"  rel="stylesheet" />\n<link href="//ep01.epimg.net/estilos/v2.x/v2.1/cabecera.css"  rel="stylesheet" />\n<link href="//ep01.epimg.net/estilos/v2.x/v2.1/portadilla.css"  rel="stylesheet" />\n<link href="//ep01.epimg.net/estilos/v2.x/v2.1/cintillos.css"  rel="stylesheet" />\n<link href="//ep01.epimg.net/estilos/v2.x/v2.1/comercial.css"  rel="stylesheet" />\n<script type="text/javascript" src="//ep01.epimg.net/js ...

# %% [markdown]
# This is an API that returns the current position of the ISS:

# %%
r = requests.get('http://api.open-notify.org/iss-now.json')
r.status_code
# Out:
# 200

# %%
r.content
# Out:
# b'{"timestamp": 1544378218, "iss_position": {"longitude": "99.7949", "latitude": "-41.0630"}, "message": "success"}'

# %% [markdown]
# We can convert a json-formatted string such as the one we get in the response into a Python object with the json library:

# %%
import json 

pos = json.loads(r.content)
pos
# Out:
# {'iss_position': {'latitude': '-41.0630', 'longitude': '99.7949'},
#  'message': 'success',
#  'timestamp': 1544378218}

# %%
pos['iss_position']['latitude']
# Out:
# '-41.0630'

# %%
import pandas as pd

pd.read_json('http://api.open-notify.org/iss-now.json')
# Out:
#            iss_position  message           timestamp
# latitude       -41.1365  success 2018-12-09 17:57:00
# longitude       99.9281  success 2018-12-09 17:57:00

# %% [markdown]
# We also can go in the other direction and generate json-formatted strings from Python objects:

# %%
mi_diccionario = {'Chicago' : "Illinois", "Kansas City" : ["Kansas", "Missouri"]}

# %%
mi_diccionario
# Out:
# {'Chicago': 'Illinois', 'Kansas City': ['Kansas', 'Missouri']}

# %%
json.dumps(mi_diccionario)
# Out:
# '{"Chicago": "Illinois", "Kansas City": ["Kansas", "Missouri"]}'

# %% [markdown]
# #### Exercise:
# Write a function that returns the duration of the next 5 overhead passes of the ISS for a given latitude and longitude. Use http://open-notify.org/Open-Notify-API/ISS-Pass-Times/
# . We are going to need to encode the parameters in the url as per the specification.
#
# For example, for Madrid:
#
# http://api.open-notify.org/iss-pass.json?lat=40.4&lon=-3.7

# %%
def get_iss(lat, lon):
    
    url = "http://api.open-notify.org/iss-pass.json?lat=%f&lon=%f" % (lat, lon)
    response = requests.get(url)
    my_dict = json.loads(response.content)
    result = my_dict['response']
    
    return result

get_iss(40.0, 3.5)
# Out:
# [{'duration': 600, 'risetime': 1544375994},
#  {'duration': 632, 'risetime': 1544381778},
#  {'duration': 383, 'risetime': 1544387650},
#  {'duration': 423, 'risetime': 1544436084},
#  {'duration': 638, 'risetime': 1544441727}]

# %% [markdown]
# Although we managed to get the response, more complicated sets of parameters will be a complicated and error-prone thing to encode. Thankfully, the `requests` library can do that work for us.

# %%
madrid_coords = {'lat': 40.4, 'lon': -3.7}

r = requests.get('http://api.open-notify.org/iss-pass.json', params=madrid_coords)
json.loads(r.content)
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1544375482,
#   'latitude': 40.4,
#   'longitude': -3.7,
#   'passes': 5},
#  'response': [{'duration': 579, 'risetime': 1544375917},
#   {'duration': 639, 'risetime': 1544381702},
#   {'duration': 514, 'risetime': 1544387526},
#   {'duration': 72, 'risetime': 1544436215},
#   {'duration': 612, 'risetime': 1544441679}]}

# %%
resp = json.loads(r.content)['response']

pd.DataFrame(resp)
# Out:
#    duration    risetime
# 0       579  1544375917
# 1       639  1544381702
# 2       514  1544387526
# 3        72  1544436215
# 4       612  1544441679

# %% [markdown]
# Even more complicated sets of parameters are sometimes required. When that is the case, API designers often decide to require them in json format, received via a `POST` request.
#
# For example, take a look at the [QPX api from Google](https://developers.google.com/qpx-express/v1/trips/search). In the documentation, they define the body of the request, which we will have to provide, and of the response, which they'll provide back.

# %%
help(requests.post)
# Out:
# Help on function post in module requests.api:
#
# post(url, data=None, json=None, **kwargs)
#     Sends a POST request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param data: (optional) Dictionary (will be form-encoded), bytes, or file-like object to send in the body of the :class:`Request`.
#     :param json: (optional) json data to send in the body of the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %% [markdown]
# # Web scraping
#
# ![HTML to DOM](http://www.cs.toronto.edu/~shiva/cscb07/img/dom/treeStructure.png)
#
# ![DOM TREE](http://www.openbookproject.net/tutorials/getdown/css/images/lesson4/HTMLDOMTree.png)

# %%
from IPython.display import IFrame

# %%
IFrame('https://aflcio.org/what-unions-do/social-economic-justice/advocacy/legislative-alerts', 400, 400)
# Out:
#         <iframe
#             width="400"
#             height="400"
#             src="https://aflcio.org/what-unions-do/social-economic-justice/advocacy/legislative-alerts"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from bs4 import BeautifulSoup

r = requests.get('https://aflcio.org/what-unions-do/social-economic-justice/advocacy/legislative-alerts')

page = r.content
page[:1000]
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n  <head>\n    <meta charset="utf-8" /><script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s'

# %%
soup = BeautifulSoup(page, 'html5lib')
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"

# %%
print(soup.prettify()[28700:30500])
# Out:
# /h5>
#                   <h2 class="content-title">
#                    <span>
#                     Letter Opposing Nominations to the Merit Systems Protection Board
#                    </span>
#                   </h2>
#                   <time datetime="2018-08-29T15:19:53-0400">
#                    August 29, 2018
#                   </time>
#                  </div>
#                 </a>
#                 <div>
#                 </div>
#                </div>
#               </div>
#               <div class="block block-content col-12 col-lg-4">
#                <div class="content-details ">
#                 <a class="b-inner" href="/about/advocacy/legislative-alerts/letter-opposing-bill-would-undermine-financial-market-regulation">
#                  <div class="b-text">
#                   <h5 class="content-type">
#                    Legislative Alert
#                   </h5>
#                   <h2 class="content-title">
#                    <span>
#                     Letter Opposing Bill That Would Undermine Financial Market Regulation
#                    </span>
#                   </h2>
#                   <time datetime="2018-07-18T14:43:45-0400">
#                    July 18, 2018
#                   </time>
#                  </div>
#                 </a>
#                 <div>
#                 </div>
#                </div>
#               </div>
#               <div class="block block-content col-12 col-lg-4">
#                <div class="content-details ">
#                 <a class="b-inner" href="/about/advocacy/legislative-alerts/letter-opposing-ryan-bounds-nomination-us-court-appeals-0">
#                  <div class="b-text">
#                   <h5 class="content-type">
#                    Legislative Alert
#                   </h5>
#                   <h2 class="content-title">
#                    <span>

# %%
help(soup.find_all)
# Out:
# Help on method find_all in module bs4.element:
#
# find_all(name=None, attrs={}, recursive=True, text=None, limit=None, **kwargs) method of bs4.BeautifulSoup instance
#     Extracts a list of Tag objects that match the given
#     criteria.  You can specify the name of the Tag and any
#     attributes you want the Tag to have.
#
#     The value of a key-value pair in the 'attrs' map can be a
#     string, a list of strings, a regular expression object, or a
#     callable that takes a string and returns whether or not the
#     string matches for some custom definition of 'matches'. The
#     same is true of the tag name.

# %%
alerts = soup.find_all('div', class_='content-details')
print(len(alerts))
type(alerts)
# Out:
# 18
# bs4.element.ResultSet

# %%
alerts[0]
# Out:
# <div class="content-details ">
# 	<a class="b-inner" href="/aboutadvocacylegislative-alerts/letter-opposing-nomination-eric-murphy-us-court-appeals-sixth">
# 	  <div class="b-text">
#               <h5 class="content-type">Legislative Alert</h5>
#         <h2 class="content-title"><span>Letter Opposing the Nomination of Eric Murphy to the U.S. Court of Appeals Sixth Circuit</span>
# </h2>
#               <time datetime="2018-11-14T15:22:18-0500">November 14, 2018</time>
#           </div>
# 	</a>
#   <div></div>
# </div>

# %%
first = alerts[0]
print(first.find('time').get_text())
print(first.a.find('span').get_text())
print(first.a['href'])
# Out:
# November 14, 2018
# Letter Opposing the Nomination of Eric Murphy to the U.S. Court of Appeals Sixth Circuit
# /aboutadvocacylegislative-alerts/letter-opposing-nomination-eric-murphy-us-court-appeals-sixth

# %%
def get_aflcio_alerts():
    result = []
    r = requests.get('http://www.aflcio.org/Legislation-and-Politics/Legislative-Alerts')
    soup = BeautifulSoup(r.content, 'html5lib')
    
    for alert in soup.find_all('div', class_='content-details'):
        dictionary = {}
        dictionary['date'] = alert.find('time').get_text()
        dictionary['title'] = alert.a.find('span').get_text()
        dictionary['link'] = 'http://www.aflcio.org' + alert.a['href']
        
        result.append(dictionary)
        
    return result

# %%
letters = get_aflcio_alerts()
letters[:2]
# Out:
# [{'date': 'November 14, 2018',
#   'link': 'http://www.aflcio.org/aboutadvocacylegislative-alerts/letter-opposing-nomination-eric-murphy-us-court-appeals-sixth',
#   'title': 'Letter Opposing the Nomination of Eric Murphy to the U.S. Court of Appeals Sixth Circuit'},
#  {'date': 'November 14, 2018',
#   'link': 'http://www.aflcio.org/aboutadvocacylegislative-alerts/letter-opposing-nomination-chad-readler-us-court-appeals-sixth',
#   'title': 'Letter Opposing the Nomination of Chad Readler to the U.S. Court of Appeals Sixth Circuit'}]

# %%
# And we come full circle! We encode the list we created in 
# a json string. We could then provide that over the internet
# in our own API!!

json.dumps(letters)[:1000]
# Out:
# '[{"date": "November 14, 2018", "title": "Letter Opposing the Nomination of Eric Murphy to the U.S. Court of Appeals Sixth Circuit", "link": "http://www.aflcio.org/aboutadvocacylegislative-alerts/letter-opposing-nomination-eric-murphy-us-court-appeals-sixth"}, {"date": "November 14, 2018", "title": "Letter Opposing the Nomination of Chad Readler to the U.S. Court of Appeals Sixth Circuit", "link": "http://www.aflcio.org/aboutadvocacylegislative-alerts/letter-opposing-nomination-chad-readler-us-court-appeals-sixth"}, {"date": "September 26, 2018", "title": "Letter Supporting Legislation That Strengthens U.S. Copyright Office", "link": "http://www.aflcio.org/aboutadvocacylegislative-alerts/letter-supporting-legislation-strengthens-us-copyright-office"}, {"date": "September 13, 2018", "title": "Letter Opposing Bill That Would Threaten Health Care Coverage For Millions", "link": "http://www.aflcio.org/about/advocacy/legislative-alerts/letter-opposing-bill-would-threaten-health-care-coverage'

# %% [markdown]
# # Annex: ultra easy scraping with pandas!
#
# When the data we want is already formatted as a table, we can do it even more easily! Just use `pandas.read_html`:

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_accidents_and_disasters_by_death_toll', header=0)

# %%
tables[4].head()
# Out:
#    Deaths             Date                                           Incident  \
# 0   20000      30 May 1626  Wanggongchang Explosion in Beijing, China in t...
# 1    3000   18 August 1769  A lightning bolt caused the Brescia Explosion ...
# 2  3,000?  1 November 1948  Boiler and ammunition explosion aboard an unid...
# 3    1950  6 December 1917       Halifax Explosion in Nova Scotia, Canada[59]
# 4    1500      8 June 1941  Ammunition plant with facilities explode at Sm...
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# # Annex II: exercises

# %% [markdown]
# ### Exercise:
#
# Extract the date of the worst aviation disaster from: https://en.wikipedia.org/wiki/List_of_accidents_and_disasters_by_death_toll
#
# Prerequisites: pandas, pd.read_html

# %%
aviation = pd.read_html('https://en.wikipedia.org/wiki/List_of_accidents_and_disasters_by_death_toll', header=0)[2]
aviation.head(1)['Date']
# Out:
# 0    27 March 1977
# Name: Date, dtype: object

# %% [markdown]
# ### Exercise:
#
# Assuming the list is exhaustive, calculate how many people died in accidental explosions per decade in the XX century. Plot it.
#
# Data:
# https://en.wikipedia.org/wiki/List_of_accidents_and_disasters_by_death_toll
#
# Prerequisites: pandas, pd.read_html, pd.to_datetime, matplotlib or seaborn

# %%
explosions = pd.read_html('https://en.wikipedia.org/wiki/List_of_accidents_and_disasters_by_death_toll', header=0)[4]
explosions.head()
# Out:
#    Deaths             Date                                           Incident  \
# 0   20000      30 May 1626  Wanggongchang Explosion in Beijing, China in t...
# 1    3000   18 August 1769  A lightning bolt caused the Brescia Explosion ...
# 2  3,000?  1 November 1948  Boiler and ammunition explosion aboard an unid...
# 3    1950  6 December 1917       Halifax Explosion in Nova Scotia, Canada[59]
# 4    1500      8 June 1941  Ammunition plant with facilities explode at Sm...
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
explosions['date'] = explosions['Date'].str[8:18]

# %%
explosions['Deaths'] = pd.to_numeric(explosions.Deaths.str.replace('[^0-9]', ''))

# %%
explosions['Decade'] = explosions['date'].str[:3] + '0s'

# %%
twentieth_century = explosions[(explosions['Decade'] > '1900') & (explosions['Decade'] < '2000')]
per_decade = twentieth_century.groupby('Decade')['Deaths'].sum()

# %%
import seaborn as sns
# %matplotlib inline

sns.barplot(data=twentieth_century, 
            x='Decade', 
            y='Deaths', 
            order=sorted(twentieth_century['Decade'].unique()),
            ci=None,
            color='darkgrey')

# %% [markdown]
# ### Exercise:
#
# create a function that, given the two tables extracted from http://en.wikipedia.org/wiki/List_of_S%26P_500_companies and a date, returns the list of companies in the S&P 500 at that date.

# %%
def companies_at_date(url, date):
    df = pd.read_html(url, header=0)[0]
    df['Date first added[3][4]'] = pd.to_datetime(df.iloc[:,6])
    return df[df['Date first added[3][4]'] < date]['Security'].unique()

list_compies = companies_at_date('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies', '2014-12-03')
list_compies
# Out:
# array(['Abbott Laboratories', 'AbbVie Inc.', 'Accenture plc',
#        'Adobe Systems Inc', 'AES Corp', 'Affiliated Managers Group Inc',
#        'AFLAC Inc', 'Agilent Technologies Inc',
#        'Air Products & Chemicals Inc', 'Akamai Technologies Inc',
#        'Alexion Pharmaceuticals', 'Allegion', 'Allergan, Plc',
#        'Alliance Data Systems', 'Allstate Corp', 'Alphabet Inc Class A',
#        'Alphabet Inc Class C', 'Amazon.com Inc.', 'Ameren Corp',
#        'American Express Co', 'American International Group, Inc.',
#        'American Tower Corp.', 'Ameriprise Financial',
#        'AmerisourceBergen Corp', 'AMETEK Inc.', 'Amgen Inc.',
#        'Amphenol Corp', 'Anadarko Petroleum Corp', 'Analog Devices, Inc.',
#        'Anthem Inc.', 'Aon plc', 'Apache Corporation',
#        'Apartment Investment & Management (Aimco)', 'Apple Inc.',
#        'Applied Materials Inc.', 'Aptiv Plc', 'Archer-Daniels-Midland Co',
#        'Arconic Inc.', 'Assurant Inc.', 'AT&T Inc.', 'Autodesk Inc.',
#        'Automatic Data Processing', 'AutoZone Inc',
#        'AvalonBay Communities, Inc.', 'Avery Dennison Corp', 'Ball Corp',
#        'Bank of America Corp', 'The Bank of New York Mellon Corp.',
#        'Baxter International Inc.', 'BB&T Corporation',
#        'Becton Dickinson', 'Berkshire Hathaway', 'Best Buy Co. Inc.',
#        'Biogen Inc.', 'BlackRock', 'Block H&R', 'Booking Holdings Inc',
#        'BorgWarner', 'Boston Properties', 'Boston Scientific', 'Broadcom',
#        'Brown-Forman Corp.', 'C. H. Robinson Worldwide',
#        'Cabot Oil & Gas', 'Capital One Financial', 'Cardinal Health Inc.',
#        'Carmax Inc', 'Carnival Corp.', 'CBRE Group', 'CBS Corp.',
#        'Celgene Corp.', 'CenterPoint Energy', 'CenturyLink Inc', 'Cerner',
#        'CF Industries Holdings Inc', 'Charles Schwab Corporation',
#        'Chipotle Mexican Grill', 'Chubb Limited', 'CIGNA Corp.',
#        'Cimarex Energy', 'Cincinnati Financial', 'Cintas Corporation',
#        'Cisco Systems', 'Citigroup Inc.', 'Citrix Systems',
#        'The Clorox Company', 'CME Group Inc.', 'CMS Energy',
#        'Cognizant Technology Solutions', 'Comerica Inc.',
#        'Conagra Brands', 'Constellation Brands', 'Costco Wholesale Corp.',
#        'Crown Castle International Corp.', 'CSX Corp.', 'Cummins Inc.',
#        'DaVita Inc.', 'Delta Air Lines Inc.', 'Dentsply Sirona',
#        'Devon Energy Corp.', 'Discover Financial Services',
#        'Discovery Inc. Class A', 'Discovery Inc. Class C',
#        'Dollar General', 'Dollar Tree', 'Dover Corp.', 'Duke Energy',
#        'E*Trade', 'Eastman Chemical', 'Ecolab Inc.',
#        'Edwards Lifesciences', 'Electronic Arts',
#        'Emerson Electric Company', 'EOG Resources', 'Equifax Inc.',
#        'Equity Residential', 'Essex Property Trust, Inc.',
#        'Estee Lauder Cos.', 'Expedia Group', 'Expeditors',
#        'Express Scripts', 'F5 Networks', 'Facebook, Inc.', 'Fastenal Co',
#        'FedEx Corporation', 'Fidelity National Information Services',
#        'Fiserv Inc', 'FLIR Systems', 'Flowserve Corporation',
#        'Fluor Corp.', 'FMC Corporation', 'Gap Inc.', 'Garmin Ltd.',
#        'General Mills', 'General Motors', 'Genuine Parts',
#        'Gilead Sciences', 'Goldman Sachs Group', 'Grainger (W.W.) Inc.',
#        'Harris Corporation', 'Hasbro Inc.', 'HCP Inc.',
#        'Helmerich & Payne', 'Hess Corporation', 'Home Depot',
#        "Honeywell Int'l Inc.", 'Hormel Foods Corp.',
#        'Host Hotels & Resorts', 'HP Inc.', 'Illinois Tool Works',
#        'Ingersoll-Rand PLC', 'Intel Corp.', 'Intercontinental Exchange',
#        'Interpublic Group', 'Intl Flavors & Fragrances', 'Intuit Inc.',
#        'Intuitive Surgical Inc.', 'Invesco Ltd.',
#        'Iron Mountain Incorporated', 'Jacobs Engineering Group',
#        'Jefferies Financial Group', 'JM Smucker', 'Johnson & Johnson',
#        'Johnson Controls International', 'JPMorgan Chase & Co.',
#        'Kansas City Southern', 'KeyCorp', 'Kimco Realty', 'Kinder Morgan',
#        'L Brands Inc.', 'Laboratory Corp. of America Holding',
#        'Lam Research', 'Lennar Corp.', 'Lilly (Eli) & Co.',
#        'Lincoln National', 'Linde plc', 'Lockheed Martin Corp.',
#        "Lowe's Cos.", 'LyondellBasell', 'Macerich', 'Marathon Oil Corp.',
#        'Marathon Petroleum', 'Marsh & McLennan',
#        'Martin Marietta Materials', 'Masco Corp.', 'Mastercard Inc.',
#        'Mattel Inc.', "McDonald's Corp.", 'Medtronic plc',
#        'Michael Kors Holdings', 'Microchip Technology',
#        'Micron Technology', 'Microsoft Corp.', 'Mohawk Industries',
#        'Molson Coors Brewing Company', 'Mondelez International',
#        'Monster Beverage', 'The Mosaic Company', 'Mylan N.V.',
#        'Nasdaq, Inc.', 'National Oilwell Varco Inc.', 'NetApp',
#        'Netflix Inc.', 'Newell Brands', 'Newfield Exploration Co',
#        'Newmont Mining Corporation', 'News Corp. Class A',
#        'NextEra Energy', 'Nielsen Holdings', 'Nike', 'Noble Energy Inc',
#        'Nordstrom', 'Northrop Grumman Corp.', 'NRG Energy', 'Nucor Corp.',
#        'Nvidia Corporation', "O'Reilly Automotive",
#        'Occidental Petroleum', 'ONEOK', 'Oracle Corp.', 'PACCAR Inc.',
#        'Parker-Hannifin', 'Pentair plc', "People's United Financial",
#        'PerkinElmer', 'Perrigo', 'Philip Morris International',
#        'Phillips 66', 'Pioneer Natural Resources',
#        'PNC Financial Services', 'Polo Ralph Lauren Corp.',
#        'Principal Financial Group', 'Progressive Corp.', 'Prologis',
#        'Prudential Financial', 'Public Storage', 'Pulte Homes Inc.',
#        'PVH Corp.', 'Quanta Services Inc.', 'Quest Diagnostics',
#        'Red Hat Inc.', 'Regeneron', 'Regions Financial Corp.',
#        'Republic Services Inc', 'Robert Half International',
#        'Roper Technologies', 'Ross Stores', 'Salesforce.com',
#        'SCANA Corp', 'Schlumberger Ltd.', 'Seagate Technology',
#        'Sherwin-Williams', 'Simon Property Group Inc', 'Snap-on',
#        'Southwest Airlines', 'Stanley Black & Decker', 'Stryker Corp.',
#        'SunTrust Banks', 'Symantec Corp.', 'Sysco Corp.', 'Target Corp.',
#        'TE Connectivity Ltd.', 'TechnipFMC', 'Textron Inc.',
#        'Tiffany & Co.', 'TJX Companies Inc.', 'Torchmark Corp.',
#        'Total System Services', 'Tractor Supply Company',
#        'The Travelers Companies Inc.', 'TripAdvisor',
#        'Twenty-First Century Fox Class A', 'Under Armour Class C',
#        'United Health Group Inc.', 'United Parcel Service',
#        'United Rentals, Inc.', 'Universal Health Services, Inc.',
#        'Unum Group', 'V.F. Corp.', 'Varian Medical Systems', 'Ventas Inc',
#        'Verisign Inc.', 'Verizon Communications',
#        'Vertex Pharmaceuticals Inc', 'Visa Inc.', 'Vulcan Materials',
#        'Walmart', 'Walgreens Boots Alliance', 'The Walt Disney Company',
#        'Wec Energy Group Inc', 'WellCare', 'Wells Fargo',
#        'Welltower Inc.', 'Western Digital', 'Williams Cos.',
#        'Wynn Resorts Ltd', 'Xilinx', 'Xylem Inc.', 'Yum! Brands Inc',
#        'Zimmer Biomet Holdings', 'Zions Bancorp', 'Zoetis'], dtype=object)
